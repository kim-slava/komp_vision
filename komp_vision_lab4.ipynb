# %% [markdown]
# <a href="https://colab.research.google.com/github/kim-slava/komp_vision/blob/main/komp_vision_lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#погрузка yolo и всех ее зависимостей
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15393, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 15393 (delta 9), reused 16 (delta 6), pack-reused 15369
# Receiving objects: 100% (15393/15393), 14.37 MiB | 24.21 MiB/s, done.
# Resolving deltas: 100% (10519/10519), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !unzip -q ../dataset.zip -d ../             # папку с датасетом загружаем в корень и разархивируем
# Out:
# replace ../dataset/images/train/111.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# обучаем img 896
# img: размер изображения, квадратный.
# batch: размер партии
# epochs: количество эпох
# data: файл данных YAML, содержащий информацию о наборе данных (путь к изображениям, меткам) (его загрузить в yolo/data)
# workers: количество процессорных рабочих
# cfg: Файл конфигурации модели архитектуры, Есть 4 варианта доступны: yolo5s.yaml, yolov5m.yaml, yolov5l.yaml, yolov5x.yaml.
# weights: Предварительно натренированные веса

# !python train.py --img 896 --cfg yolov5l.yaml --batch 8 --epoch 150 --data castom_data.yaml --weights yolov5l.pt --name result --workers 2
# Out:
# train: weights=yolov5l.pt, cfg=yolov5l.yaml, data=castom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=8, imgsz=896, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-129-gb54fd0a Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/best (2).pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-4-14 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      48             try:
# ---> 49                 model = DetectMultiBackend(path, device=device, fuse=autoshape)  # detection model
#      50                 if autoshape:
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in __init__(self, weights, device, dnn, data, fp16, fuse)
#     343         if pt:  # PyTorch
# --> 344             model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

import os

img = os.path.join('data', 'images', '/content/2.jpg')
results = model(img)

# plt.imshow(np.squeeze(results.render()))
# plt.axis('off')

im1=np.squeeze(results.render())
img = cv2.cvtColor(im1, cv2.COLOR_RGB2BGR)
cv2.imwrite('/content/im.jpg', img)
# Out:
# True

# %%
# !python detect.py --weights /content/yolov5/runs/train/result/weights/best.pt --conf 0.25 --source https://antonenko-media.com/wp-content/uploads/2021/02/03523454654-scaled.jpg

# %%
img = os.path.join('data', 'images', '/content/0.jpg')
results = model(img)

im1=np.squeeze(results.render())
img = cv2.cvtColor(im1, cv2.COLOR_RGB2BGR)
cv2.imwrite('/content/im.jpg', img)
# Out:
# True

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/best (2).pt', force_reload=True)

img = os.path.join('data', 'images', '/content/1.jpg')
results = model(img)

# plt.imshow(np.squeeze(results.render()))
# plt.axis('off')

im1=np.squeeze(results.render())
img = cv2.cvtColor(im1, cv2.COLOR_RGB2BGR)
cv2.imwrite('/content/im.jpg', img)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-4-14 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      48             try:
# ---> 49                 model = DetectMultiBackend(path, device=device, fuse=autoshape)  # detection model
#      50                 if autoshape:
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in __init__(self, weights, device, dnn, data, fp16, fuse)
#     343         if pt:  # PyTorch
# --> 344             model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
# ...
